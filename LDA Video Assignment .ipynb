# %% [markdown]
# ## Linear Discriminant Analysis (LDA) Assignment

# %% [markdown]
# ## 1. The given dataset "Parkinson_Dataset_2" contains data from class 0 and 1. Split the dataset into 90:10 train - test ratio.

# %%
import numpy as np
import pandas as pd 
import sklearn.model_selection as spltfunc
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Parkinson_Dataset_2.csv')
x=df.iloc[::,2:755]
y=df['class']
X_train, x_test, Y_train, y_test = spltfunc.train_test_split(x, y, train_size=0.90,test_size=0.10, random_state=2)

# %%
x
# Out:
#      gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0       1.0  0.82127  0.66846  0.26212      375.0             374.0
# 1       0.0  0.88352  0.79509  0.36585      397.0             396.0
# 2       0.0  0.20452  0.70358  0.67909      286.0             285.0
# 3       0.0  0.34488  0.62269  0.48573      443.0             441.0
# 4       0.0  0.84627  0.61553  0.58034      480.0             479.0
# ..      ...      ...      ...      ...        ...               ...
# 497     1.0  0.69954  0.72157  0.74223      203.0             202.0
# 498     0.0  0.83312  0.64741  0.34923      330.0             329.0
# 499     0.0  0.81096  0.70200  0.35042      341.0             340.0
# 500     0.0  0.78645  0.68320  0.59472      323.0             321.0
# 501     1.0  0.15273  0.69326  0.58112      348.0             346.0
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0            0.005139            0.000044       0.00086      0.000004  ...
# 1            0.004861            0.000054       0.00143      0.000007  ...
# 2            0.006754            0.002272       0.00333      0.000023  ...
# 3            0.004353            0.000628       0.00233      0.000010  ...
# 4            0.004019            0.000027       0.00052      0.000002  ...
# ..                ...                 ...           ...           ...  ...
# 497          0.009508            0.000151       0.00454      0.000043  ...
# 498          0.005855            0.000049       0.00095      0.000006  ...
# 499          0.005662            0.000034       0.00072      0.000004  ...
# 500          0.005960            0.000588       0.00446      0.000027  ...
# 501          0.005532            0.001452       0.00359      0.000020  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 0                      30.5070                    11.9821
# 1                       1.6020                     1.5935
# 2                      12.0527                     3.2624
# 3                      42.5939                    52.3417
# 4                       4.0908                     4.8888
# ..                         ...                        ...
# 497                     1.5909                     1.5098
# 498                     7.0681                   118.5761
# 499                     5.0916                    27.2050
# 500                     3.5834                    38.9374
# 501                     1.8450                     6.0657
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 0                       6.5816                     6.1763
# 1                       2.2826                     2.6744
# 2                       3.3508                     3.3938
# 3                      29.9333                     7.1216
# 4                       3.3080                     2.3842
# ..                         ...                        ...
# 497                     1.5915                    28.7679
# 498                    93.6072                    75.3398
# 499                    17.0972                     4.0329
# 500                    35.6879                    33.4331
# 501                     3.1588                     2.9695
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 0                       4.8050                     4.6671
# 1                       2.4310                     2.8983
# 2                       3.5254                     3.3666
# 3                       3.5414                     3.1618
# 4                       2.8639                     2.5491
# ..                         ...                        ...
# 497                    46.6746                    54.1454
# 498                    74.4227                    80.0808
# 499                     3.5933                     4.7936
# 500                    36.6657                    51.4946
# 501                     2.5653                     2.3974
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 0                       5.8098                     6.1651
# 1                       8.2023                    17.1918
# 2                       4.1292                     5.7149
# 3                       2.9177                    19.8108
# 4                       2.4263                     3.7174
# ..                         ...                        ...
# 497                    48.9675                    43.7105
# 498                    66.1968                    51.4639
# 499                     9.5516                     6.6749
# 500                    49.8463                    43.8060
# 501                     2.4948                     5.7007
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 0                       4.5811                     6.2012
# 1                      16.8211                    68.1856
# 2                       3.9599                     3.3665
# 3                      35.6502                    62.9818
# 4                       4.6597                     5.4125
# ..                         ...                        ...
# 497                    36.3226                    79.6239
# 498                    46.0588                    93.1224
# 499                     3.7209                    27.4980
# 500                    41.4489                    90.6155
# 501                     8.1208                     2.9888
#
# [502 rows x 753 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 497    1
# 498    1
# 499    1
# 500    1
# 501    1
# Name: class, Length: 502, dtype: int64

# %%
X_train
# Out:
#        gender       PPE       DFA      RPDE   numPulses  numPeriodsPulses  \
# 176  0.097447  0.799706  0.780174  0.400959  312.825966        310.923413
# 372  1.000000  0.810700  0.699540  0.423020  332.000000        331.000000
# 24   0.000000  0.860800  0.712660  0.400570  460.000000        459.000000
# 383  1.000000  0.466710  0.821470  0.650970  252.000000        251.000000
# 417  1.000000  0.827590  0.635580  0.375210  344.000000        343.000000
# ..        ...       ...       ...       ...         ...               ...
# 22   0.000000  0.180080  0.800060  0.512010  313.000000        312.000000
# 72   0.000000  0.831720  0.578490  0.360170  375.000000        374.000000
# 493  1.000000  0.119070  0.702590  0.573100  356.000000        354.000000
# 15   0.000000  0.857160  0.553200  0.348180  497.000000        496.000000
# 168  0.264929  0.696716  0.660811  0.526245  301.145497        300.145497
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 176          0.006175            0.001468      0.002345      0.000015  ...
# 372          0.005810            0.000032      0.000930      0.000005  ...
# 24           0.004194            0.000042      0.001260      0.000005  ...
# 383          0.007645            0.000138      0.006710      0.000051  ...
# 417          0.005612            0.000053      0.001210      0.000007  ...
# ..                ...                 ...           ...           ...  ...
# 22           0.006151            0.001157      0.002470      0.000015  ...
# 72           0.005147            0.000036      0.000880      0.000005  ...
# 493          0.005412            0.000742      0.001730      0.000009  ...
# 15           0.003883            0.000019      0.000370      0.000001  ...
# 168          0.006421            0.000135      0.002130      0.000014  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 176                   3.164206                  19.008124
# 372                   1.853300                   1.767600
# 24                    2.114700                   2.223600
# 383                   1.619300                   1.745500
# 417                  57.305900                 160.661100
# ..                         ...                        ...
# 22                    2.683600                  15.769000
# 72                   10.617400                   2.983000
# 493                   7.538700                  11.012100
# 15                    5.416900                   3.174500
# 168                   2.480276                 118.397043
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 176                  15.137630                  12.782879
# 372                   1.741000                   2.009400
# 24                   59.454100                  12.605600
# 383                  10.894100                   5.564100
# 417                 130.045500                 100.798900
# ..                         ...                        ...
# 22                   10.829700                   8.844800
# 72                    3.378500                   3.169100
# 493                   9.240700                   2.845400
# 15                    2.848200                   2.818900
# 168                 109.040486                  89.819397
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 176                  11.468190                   9.088951
# 372                   2.508400                   2.557900
# 24                    2.681800                   1.932700
# 383                   4.999900                   6.855600
# 417                  56.309600                  32.918100
# ..                         ...                        ...
# 22                    4.457800                   5.280900
# 72                    2.923400                   2.566200
# 493                   2.930400                   2.704100
# 15                    3.078200                   2.936800
# 168                  74.805933                  61.598749
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 176                   7.979571                   8.616823
# 372                   2.620100                   4.303800
# 24                    1.948700                   5.418000
# 383                   9.807500                  10.796100
# 417                  39.158900                  46.231300
# ..                         ...                        ...
# 22                    4.148500                   3.645400
# 72                    2.462100                   2.762900
# 493                   4.052800                  10.149000
# 15                    3.191500                   3.442400
# 168                  49.413195                  37.208653
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 176                   8.260792                   3.945423
# 372                  19.713400                  46.029100
# 24                    5.389900                   6.320300
# 383                   8.942600                  14.705600
# 417                  38.287400                  42.754600
# ..                         ...                        ...
# 22                    3.664100                   3.294100
# 72                    3.073500                   5.119000
# 493                  12.780900                  71.290100
# 15                    3.469600                   4.117500
# 168                  29.907452                  15.026444
#
# [451 rows x 753 columns]

# %%
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor)
plt.show()

# %%
trydf=df.iloc[::,0:10]
#trydf=df
sns.heatmap(trydf.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. PerformLDAonthedatasetonthe90%split.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.tree import DecisionTreeClassifier # Used for checking the performance of LDA

# %%
tree = DecisionTreeClassifier(criterion="entropy")
tree.fit(X_train,Y_train)
accuracy = tree.score(x_test,y_test)
print("Accuracy",accuracy*100)
# Out:
# Accuracy 92.15686274509804

# %%
lda=LDA(n_components=1)
lda.fit(X_train, Y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=1)

# %%
lda.score(x_test,y_test)
# Out:
# 0.803921568627451

# %% [markdown]
# ## 3. Test the accuracy on the 10% split

# %%
# Fit the method's model
lda.fit(X_train, Y_train)

# Fit a Decision Tree classifier on the embedded training set
tree.fit(lda.transform(X_train), Y_train)

# Compute the Decision Tree accuracy on the embedded test set
acc = tree.score(lda.transform(x_test), y_test)

# %%
acc*100
# Out:
# 80.3921568627451
